# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshitgosain/Tensorflow-ZTM/blob/main/TF_ZTM_Section2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# If you can build a simple rule-based system that doesn't require machine learning. make that a priority

# %% [markdown]
# #What is deep Learning Good For?
# - Problem with long list of rules.
# - Continually changing environments
# - Discovering Insights with large collections of data
#
# #What is Deep learning not goof for?
# - When you need explainability
# - When a traditional rule-based approach is a better option
# - When errors are unacceptable - Since the Outputs of Deep Learning aren't always predictable
# - When you dont have much data

# %% [markdown]
# #Machine Learning VS Deep Learning
# - Traditionally Machine Learning have worked better on Structured Data than
#
#
# Common Algos-
# - Random Forest
# -Naive Bayes etc
#
# Deep Learning
# - Deep Learning works better on unstructed data (NLP , Image Data etc.)
# - NN
# Fully Connected NN
# - ANN
# -CNN
# -RNN
# -Transformers

# %% [markdown]
# #Deep Learning Use cases:
# - Recommendation
# - Translation
# - NLP
# - Speech
# - Comp. Vision

# %% [markdown]
# #What is Tensorflow:
# - End-to-end platform for ML.
# - Write fast deep learning code in py
# - Able to access any pre-built Deep Learning Models
# - Whole stack- Data processing, model data, deploy model in Application
# - Originally designed and used by Google

# %% [markdown]
# #What is a Tensor?
# We created a numerical encoding for every inpt we get to identify patterns . Those numerical encodings are tensors.
# A numerical way of representing information is a Tensor

# %% [markdown]
# #Let's Code(Actual Coding)
